# %% [markdown]
# # Columns LEGO

# %%
using LightGraphs, MetaGraphs
using Catlab, Catlab.WiringDiagrams, Catlab.Graphics

using PyCall # Needed for `PyGraphs` interop.
using CompositionalPlanning, CompositionalPlanning.PyGraphs

function visualize_plan(diagram::WiringDiagram; kw...)
    to_graphviz(diagram; label_attr=:xlabel, direction=:horizontal, kw...)
end

cd("../data")

# %% [markdown]
# ## Connectivity graph

# %% [markdown]
# Load the connectivity graph for the columns LEGO design.

# %%
connectivity_graph = read_connectivity_graph("icra.graphml")
graph = connectivity_graph.graph
# Out:
# {9, 8} directed simple Int64 graph

# %% [markdown]
# Display connectivity graph using Graphviz.

# %%
to_graphviz(connectivity_graph_to_dot(connectivity_graph))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, Catlab.Graphics.Graphviz.Statement[Node("n1", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:label=>"1")), Node("n2", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:label=>"2")), Node("n3", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:label=>"3")), Node("n4", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:label=>"4")), Node("n5", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:label=>"5")), Node("n6", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:label=>"6")), Node("n7", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:label=>"7")), Node("n8", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:fillcolor=>"gray",:label=>"8",:style=>"filled")), Node("n9", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:fillcolor=>"gray",:label=>"9",:style=>"filled")), Edge(Catlab.Graphics.Graphviz.NodeID[NodeID("n1", "", ""), NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol,Union{String, Html}}()), Edge(Catlab.Graphics.Graphviz.NodeID[NodeID("n2", "", ""), NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol,Union{String, Html}}()), Edge(Catlab.Graphics.Graphviz.NodeID[NodeID("n3", "", ""), NodeID("n7", "", "")], OrderedCollections.OrderedDict{Symbol,Union{String, Html}}()), Edge(Catlab.Graphics.Graphviz.NodeID[NodeID("n4", "", ""), NodeID("n5", "", "")], OrderedCollections.OrderedDict{Symbol,Union{String, Html}}()), Edge(Catlab.Graphics.Graphviz.NodeID[NodeID("n5", "", ""), NodeID("n7", "", "")], OrderedCollections.OrderedDict{Symbol,Union{String, Html}}()), Edge(Catlab.Graphics.Graphviz.NodeID[NodeID("n6", "", ""), NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol,Union{String, Html}}()), Edge(Catlab.Graphics.Graphviz.NodeID[NodeID("n8", "", ""), NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol,Union{String, Html}}()), Edge(Catlab.Graphics.Graphviz.NodeID[NodeID("n9", "", ""), NodeID("n6", "", "")], OrderedCollections.OrderedDict{Symbol,Union{String, Html}}())], OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:rankdir=>"BT"), OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:width=>"0",:height=>"0",:margin=>"0",:shape=>"circle"), OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:arrowsize=>"0.5"))

# %% [markdown]
# ## Planning

# %% [markdown]
# ### Plan #1: Sequential plan

# %% [markdown]
# Create a sequential plan from the full connectivity graph.

# %%
plan1 = plan = sequential_plan(graph)
nboxes(plan)
# Out:
# 8

# %%
write_graphml(plan, "icra_sequential_schedule.graphml");

# %% [markdown]
# Visualize plan without drawing the labels or the incoming or outgoing wires.

# %%
visualize_plan(plan, labels=false, outer_ports=false)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, Catlab.Graphics.Graphviz.Statement[Node("n3", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n3",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></TD>\n</TR>\n</TABLE>"))), Node("n4", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n4",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></TD>\n</TR>\n</TABLE>"))), Node("n5", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n5",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></TD>\n</TR>\n</TABLE>"))), Node("n6", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n6",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></TD>\n</TR>\n</TABLE>"))), Node("n7", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n7",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></TD>\n</TR>\n</TABLE>"))), Node("n8", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n8",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></TD>\n</TR>\n</TABLE>"))), Node("n9", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n9",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></TD>\n</TR>\n</TABLE>"))), Node("n10", OrderedCollections. ...

# %% [markdown]
# Visualize the plan with all information attached. This one is big, so we export it for viewing outside the notebook.

# %%
graphviz = visualize_plan(plan, labels=true)
open("test.svg", "w") do io
   show(io, MIME("image/svg+xml"), graphviz)
end

# %% [markdown]
# ### Plan #2: Parallel plan using Girvan-Newman algorithm

# %% [markdown]
# Identify the four columns and the roof using the [Girvan-Newman algorithm](https://en.wikipedia.org/wiki/Girvan%E2%80%93Newman_algorithm) for community detection. We cheat a little by hardcoding the number of components.

# %%
components = last(PyGraphs.nx_girvan_newman(Graph(graph), 3))
components = [ sort(collect(c)) for c in components ]
components
# Out:
# 4-element Array{Array{Int64,1},1}:
#  [1, 8]
#  [2, 3]
#  [4, 6, 9]
#  [5, 7]

# %% [markdown]
# Build a parallel plan on these five components.

# %%
plan2 = plan = parallel_plan(graph, components)
nboxes(plan)
# Out:
# 7

# %%
write_graphml(plan, "icra_parallel_plan.graphml");

# %% [markdown]
# At the top level, the five components are black boxes, connected in sequence. (The visualization is easier to read if we do not draw the ports and wires of outer box.)

# %%
visualize_plan(plan, labels=true, outer_ports=false)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, Catlab.Graphics.Graphviz.Statement[Node("n3", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n3",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></TD>\n</TR>\n</TABLE>"))), Node("n4", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n4",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></TD>\n</TR>\n</TABLE>"))), Node("n5", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n5",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in3\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></TD>\n</TR>\n</TABLE>"))), Node("n6", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n6",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></TD>\n</TR>\n</TABLE>"))), Node("n7", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n7",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></TD>\n</TR>\n</TABLE>"))), Node("n8", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n8",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></TD>\n</TR>\n</TABLE>"))), Node("n9", OrderedCollections.OrderedDict{Symbol,Union{String, Html}}(:id=>"n9",:comment=>"",:label=>Html("<TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\">\n<TR>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in1\"></TD></TR><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"in2\"></TD></TR></TABLE></TD>\n<TD BORDER=\"1\" CELLPADDING=\"4\"></TD>\n<TD><TABLE BORDER=\"0\" CELLPADDING=\"0\" CELLSPACING=\"0\"><TR><TD HEIGHT=\"24\" WIDTH=\"0\" PORT=\"out1\"></TD></TR></TABLE></ ...

# %% [markdown]
# To verify this, inspect the types of the boxes:

# %%
map(typeof, boxes(plan))
# Out:
# 7-element Array{DataType,1}:
#  Box{Nothing}
#  Box{Nothing}
#  WiringDiagram
#  Box{Nothing}
#  Box{Nothing}
#  Box{Nothing}
#  Box{Nothing}

# %% [markdown]
# Here is a sub-plan for one of the columns.

# %%
column_plan = first(boxes(plan))
visualize_plan(column_plan, labels=true)
# Out:
# MethodError: no method matching visualize_plan(::Box{Nothing}; labels=true)
# Closest candidates are:
#   visualize_plan(!Matched::WiringDiagram; kw...) at In[1]:8
#
# Stacktrace:
#  [1] top-level scope at In[13]:2

# %% [markdown]
# Expand all the sub-plans and generate one big plan.

# %%
subplans = filter(v -> box(plan,v) isa WiringDiagram, box_ids(plan))
substitute!(plan, subplans)

nboxes(plan)
# Out:
# 8

# %% [markdown]
# ## Scheduling

# %% [markdown]
# Convert the two plans into expressions and then into schedules.

# %%
steps1, steps2 = map((plan1, plan2)) do plan
    plan_expr = to_hom_expr(PlanningExpr, plan)
    steps = jsonable_schedule(interleave_hom_expr(plan_expr))
end;

# %% [markdown]
# For the first schedule, show the *smaller* piece of each join operation.

# %%
map(steps1) do (operator, inputs, outputs)
    in1, in2 = inputs
    if length(in2) >= length(in1); in1, in2 = in2, in1 end
    in2
end
# Out:
# 8-element Array{Array{Int64,1},1}:
#  [8]
#  [9]
#  [2]
#  [4]
#  [3]
#  [5]
#  [7]
#  [1, 2, 3, 8]

# %% [markdown]
# Export the schedules as JSON.

# %%
import JSON

open("icra.json", "w") do io
   JSON.print(io, steps1)
end
open("icra.json", "w") do io
   JSON.print(io, steps2)
end
